# %% [markdown]
# **PHASE 1: DATA PREPROCESSING - Load and Save Raw Data**
#
# Purpose: Load 2.4M papers from JSON and save as efficient pickle
# Input: arxiv-metadata-oai-snapshot.json (3.93 GB)
# Output: arxiv_full_raw.pkl (3.57 GB)
# ML Involved: None - Pure data loading
# Runtime: ~ 2 minutes
# Run Once: ✓ Never need to run again

# %%
#imports
import pandas as pd
import json
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from tqdm import tqdm
import os

print(f"Working directory: {os.getcwd()}")
# Out:
# Working directory: /Users/aleksandralyubarskaja/Desktop/arxiv_case_study

# %%
# check if data file exists
data_path = 'data/raw/arxiv-metadata-oai-snapshot.json'
if os.path.exists(data_path):
    size_gb = os.path.getsize(data_path) / (1024**3)
    print(f"✓ Dataset found! Size: {size_gb:.2f} GB")
else:
    print(f"x Dataset not found at: {data_path}")
    print("Download it first!")
# Out:
# ✓ Dataset found! Size: 3.93 GB

# %%
# load data in chunks and process
# only run once

# count lines first
print("Counting total papers...")
with open(data_path, 'r', encoding='utf-8', errors='ignore') as f:
    total_lines = sum(1 for _ in f)
print(f"Total papers: {total_lines:,}")

# load with error handling
print("\nLoading dataset...")
papers = []
errors = 0

with open(data_path, 'r', encoding='utf-8', errors='ignore') as f:
    for i, line in enumerate(tqdm(f, total=total_lines)):
        try:
            papers.append(json.loads(line))
        except json.JSONDecodeError:
            errors += 1
            continue  # skip bad lines

df = pd.DataFrame(papers)
print(f"\n✓ Loaded: {len(df):,} papers")
print(f"! Skipped {errors} lines with encoding issues")
print(f"Memory usage: {df.memory_usage(deep=True).sum() / 1024**3:.2f} GB")
# Out:
# Counting total papers...
# Total papers: 2,384,623
#
# Loading dataset...
# 100%|██████████| 2384623/2384623 [01:06<00:00, 35671.15it/s]
# ✓ Loaded: 2,384,622 papers
# ! Skipped 1 lines with encoding issues
# Memory usage: 4.61 GB
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[10], line 27
#      24 print(f"Memory usage: {df.memory_usage(deep=True).sum() / 1024**3:.2f} GB")
#      26 # Save as pickle
# ---> 27 df.to_pickle('data/processed/arxiv_full_raw.pkl')
#      28 print("✓ Saved as pickle for fast reloading!")
#
# File ~/Desktop/arxiv_case_study/.venv/lib/python3.13/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/Desktop/arxiv_case_study/.venv/lib/python3.13/site-packages/pandas/core/generic.py:3187, in NDFrame.to_pickle(self, path, compression, protocol, storage_options)
#    3137 """
#    3138 Pickle (serialize) object to file.
#    3139
#    (...)   3183 4    4    9
#    3184 """  # noqa: E501
#    3185 from pandas.io.pickle import to_pickle
# -> 3187 to_pickle(
#    3188     self,
#    3189     path,
#    3190     compression=compression,
#    3191     protocol=protocol,
#    3192     storage_options=storage_options,
#    3193 )
#
# File ~/Desktop/arxiv_case_study/.venv/lib/python3.13/site-packages/pandas/io/pickle.py:103, in to_pickle(obj, filepath_or_buffer, compression, protocol, storage_options)
#     100 if protocol < 0:
#     101     protocol = pickle.HIGHEST_PROTOCOL
# --> 103 with get_handle(
#     104     filepath_or_buffer,
#     105     "wb",
#     106     compression=compression,
#     107     is_text=False,
#     108     storage_options=storage_options,
#     109 ) as handles:
#     110     # letting pickle write directly to the buffer is more memory-efficient
#     111     pickle.dump(obj, handles.handle, protocol=protocol)
#
# File ~/Desktop/arxiv_case_study/.venv/lib/python3.13/site-packages/pandas/io/common.py:749, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747 # Only for write methods
#     748 if "r" not in mode and is_path:
# --> 749     check_parent_directory(str(handle))
#     751 if compression:
#     752     if compression != "zstd":
#     753         # compression libraries do not like an explicit text-mode
#
# File ~/Desktop/arxiv_case_study/.venv/lib/python3.13/site-packages/pandas/io/common.py:616, in check_parent_directory(path)
#     614 parent = Path(path).parent
#     615 if not parent.is_dir():
# --> 616     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'data/processed'

# %%
# save 

#create folder if needed
os.makedirs('data/processed', exist_ok=True)
print("✓ Processed folder ready!")

# save as pickle
df.to_pickle('data/processed/arxiv_full_raw.pkl')
print("✓ Saved as pickle for fast reloading!")

# %%
#confirm saved

pickle_path = 'data/processed/arxiv_full_raw.pkl'

if os.path.exists(pickle_path):
    size_gb = os.path.getsize(pickle_path) / 1024**3
    print(f"✓✓✓ Success! ✓✓✓")
    print(f"Pickle saved: {size_gb:.2f} GB")
else:
    print("Not saved yet")
# Out:
# ✓✓✓ SUCCESS! ✓✓✓
# Pickle saved: 3.57 GB
